# %% [markdown]
# # Project EDA

# %% [markdown]
# **Goal**: Better understand the car data set to prepare for modeling
# **Inputs**: AutoInsurance.csv
# **Outputs**: None

# %%
# import necessary packages
import numpy as np
import pandas as pd

# %%
# load and view data
car = pd.read_csv("AutoInsurance.csv")
car
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0           1           2                 3.000000        4         5
# 1     BU79786  Washington              2763.519279       No     Basic
# 2     QZ44356     Arizona              6979.535903       No  Extended
# 3     AI49188      Nevada             12887.431650       No   Premium
# 4     WW63253  California              7645.861827       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9130  LA72316  California             23405.987980       No     Basic
# 9131  PK87824  California              3096.511217      Yes  Extended
# 9132  TD14365  California              8163.890428       No  Extended
# 9133  UP19263  California              7524.442436       No  Extended
# 9134  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
# remove unecessary first row
car = car.iloc[1:]

# view dimensions
car.shape
# Out:
# (9134, 24)

# %%
# view variable names
car.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# get a better sense of some of the categorical variables
car['Policy Type'].value_counts()
# Out:
# Policy Type
# Personal Auto     6788
# Corporate Auto    1968
# Special Auto       378
# Name: count, dtype: int64

# %%
# get a better sense of some of the categorical variables
car['Vehicle Size'].value_counts()
# Out:
# Vehicle Size
# Medsize    6424
# Small      1764
# Large       946
# Name: count, dtype: int64

# %%
# get a better sense of some of the categorical variables
car['Vehicle Class'].value_counts()
# Out:
# Vehicle Class
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: count, dtype: int64

# %%
# get a better sense of some of the categorical variables
car['Coverage'].value_counts()
# Out:
# Coverage
# Basic       5568
# Extended    2742
# Premium      824
# Name: count, dtype: int64

# %%
# get a better sense of some of the categorical variables
car['State'].value_counts()
# Out:
# State
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64

# %%
# get a better sense of numerical variables
car.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...
